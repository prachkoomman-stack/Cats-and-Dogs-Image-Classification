# %%
import random
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, models, transforms
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image, ImageOps
from pathlib import Path
import matplotlib.pyplot as plt

random.seed(42)
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# Using: cuda

# %%
DATA_DIR = Path.home()/"Downloads"/"new_CatsandDogs"

IMG_SIZE = 224
BATCH_SIZE = 32
NORM_MEAN = [0.485, 0.456, 0.406]
NORM_STD = [0.229, 0.224, 0.225]

transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(NORM_MEAN, NORM_STD),
])

base = datasets.ImageFolder(DATA_DIR, transform=transform)

class_names = base.classes
labels = base.targets

idx_train, idx_rest = train_test_split(
    list(range(len(labels))), test_size=0.30, random_state=42, stratify=labels)
idx_val, idx_test = train_test_split(
    idx_rest, test_size=0.50, random_state=42, stratify=[labels[i] for i in idx_rest])

train_ds = Subset(base, idx_train)
val_ds = Subset(base, idx_val)
test_ds = Subset(base, idx_test)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, persistent_workers=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

print(f"{len(class_names)} classes: {class_names}")
print(f"{len(labels)} images total -> train {len(train_ds)} | val {len(val_ds)} | test {len(test_ds)}")

print(f"\n{'breed':<28}{'train':>7}{'val':>6}{'test':>6}")
for c, name in enumerate(class_names):
    row = [sum(1 for i in idx if labels[i] == c) for idx in (idx_train, idx_val, idx_test)]
    print(f"{name:<28}{row[0]:>7}{row[1]:>6}{row[2]:>6}")
# Out:
# 37 classes: ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# 7315 images total -> train 5120 | val 1097 | test 1098
#
# breed                         train   val  test
# Abyssinian                      136    29    29
# Bengal                          140    30    30
# Birman                          139    30    30
# Bombay                          123    27    26
# British_Shorthair               139    29    30
# Egyptian_Mau                    135    29    28
# Maine_Coon                      140    30    30
# Persian                         140    30    30
# Ragdoll                         139    30    30
# Russian_Blue                    140    30    30
# Siamese                         139    30    30
# Sphynx                          140    30    30
# american_bulldog                140    30    30
# american_pit_bull_terrier       140    30    30
# basset_hound                    140    30    30
# beagle                          140    30    30
# boxer                           139    30    30
# chihuahua                       140    30    30
# english_cocker_spaniel          137    29    30
# english_setter                  140    30    30
# german_shorthaired              138    29    30
# great_pyrenees                  139    30    30
# havanese                        140    30    30
# japanese_chin                   135    29    29
# keeshond                        134    29    29
# leonberger                      139    29    30
# miniature_pinscher              140    30    30
# newfoundland                    137    29    29
# pomeranian                      140    30    30
# pug                             140    30    30
# saint_bernard                   140    30    30
# samoyed                         140    30    30
# scottish_terrier                139    30    30
# shiba_inu                       139    30    30
# staffordshire_bull_terrier      134    29    28
# wheaten_terrier                 140    30    30
# yorkshire_terrier               140    30    30

# %%
model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, len(class_names))
model = model.to(device)

print(f"resnet18 from scratch -> {len(class_names)} classes")
# Out:
# resnet18 from scratch -> 37 classes

# %%
EPOCHS = 100
WARMUP_EPOCHS = 5
CKPT_PATH = "Oxford_pets_scratch_noaugment.pth"

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.05)

warmup = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.1, total_iters=WARMUP_EPOCHS)
cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS - WARMUP_EPOCHS)
scheduler = torch.optim.lr_scheduler.SequentialLR(optimizer, schedulers=[warmup, cosine], milestones=[WARMUP_EPOCHS])


@torch.no_grad()
def accuracy(loader):
    model.eval()
    correct = total = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        correct += (model(x).argmax(1) == y).sum().item()
        total += y.size(0)
    return correct / total


history = []
best_acc, best_epoch, best_state = -1.0, 0, None

for epoch in range(1, EPOCHS + 1):
    lr = optimizer.param_groups[0]["lr"]
    model.train()
    running_loss = correct = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * y.size(0)
        correct += (out.argmax(1) == y).sum().item()
    scheduler.step()

    train_loss = running_loss / len(train_ds)
    train_acc = correct / len(train_ds)
    val_acc = accuracy(val_loader)
    history.append((train_loss, train_acc, val_acc))

    mark = ""
    if val_acc > best_acc:
        best_acc, best_epoch = val_acc, epoch
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        mark = "  <- best so far"
    print(f"epoch {epoch:>2}/{EPOCHS}  lr {lr:.1e}  train loss {train_loss:.3f}  train acc {train_acc:.3f}  val acc {val_acc:.3f}{mark}")

model.load_state_dict(best_state)

torch.save({
    "model_state": best_state,
    "class_names": class_names,
    "arch": "resnet18",
    "img_size": IMG_SIZE,
    "norm_mean": NORM_MEAN,
    "norm_std": NORM_STD,
    "val_accuracy": best_acc,
    "epoch": best_epoch,
}, CKPT_PATH)

print(f"\nSaved epoch {best_epoch} (val accuracy {best_acc:.3f}) to {CKPT_PATH}")
# Out:
# epoch  1/100  lr 1.0e-04  train loss 3.363  train acc 0.091  val acc 0.149  <- best so far
# epoch  2/100  lr 2.8e-04  train loss 3.072  train acc 0.157  val acc 0.189  <- best so far
# epoch  3/100  lr 4.6e-04  train loss 2.835  train acc 0.197  val acc 0.149
# epoch  4/100  lr 6.4e-04  train loss 2.616  train acc 0.258  val acc 0.166
# epoch  5/100  lr 8.2e-04  train loss 2.415  train acc 0.294  val acc 0.168
# epoch  6/100  lr 1.0e-03  train loss 2.201  train acc 0.346  val acc 0.151
# epoch  7/100  lr 1.0e-03  train loss 1.857  train acc 0.442  val acc 0.286  <- best so far
# epoch  8/100  lr 1.0e-03  train loss 1.590  train acc 0.504  val acc 0.327  <- best so far
# epoch  9/100  lr 1.0e-03  train loss 1.292  train acc 0.595  val acc 0.337  <- best so far
# epoch 10/100  lr 1.0e-03  train loss 0.972  train acc 0.692  val acc 0.272
# epoch 11/100  lr 9.9e-04  train loss 0.720  train acc 0.775  val acc 0.263
# epoch 12/100  lr 9.9e-04  train loss 0.455  train acc 0.867  val acc 0.357  <- best so far
# epoch 13/100  lr 9.9e-04  train loss 0.263  train acc 0.926  val acc 0.281
# epoch 14/100  lr 9.8e-04  train loss 0.177  train acc 0.954  val acc 0.282
# epoch 15/100  lr 9.8e-04  train loss 0.111  train acc 0.973  val acc 0.341
# epoch 16/100  lr 9.7e-04  train loss 0.121  train acc 0.967  val acc 0.339
# epoch 17/100  lr 9.7e-04  train loss 0.186  train acc 0.946  val acc 0.290
# epoch 18/100  lr 9.6e-04  train loss 0.215  train acc 0.936  val acc 0.351
# epoch 19/100  lr 9.5e-04  train loss 0.193  train acc 0.940  val acc 0.280
# epoch 20/100  lr 9.5e-04  train loss 0.156  train acc 0.951  val acc 0.347
# epoch 21/100  lr 9.4e-04  train loss 0.069  train acc 0.981  val acc 0.370  <- best so far
# epoch 22/100  lr 9.3e-04  train loss 0.021  train acc 0.996  val acc 0.464  <- best so far
# epoch 23/100  lr 9.2e-04  train loss 0.006  train acc 1.000  val acc 0.467  <- best so far
# epoch 24/100  lr 9.1e-04  train loss 0.007  train acc 0.999  val acc 0.451
# epoch 25/100  lr 9.0e-04  train loss 0.004  train acc 1.000  val acc 0.483  <- best so far
# epoch 26/100  lr 8.9e-04  train loss 0.002  train acc 1.000  val acc 0.486  <- best so far
# epoch 27/100  lr 8.8e-04  train loss 0.002  train acc 1.000  val acc 0.490  <- best so far
# epoch 28/100  lr 8.7e-04  train loss 0.001  train acc 1.000  val acc 0.496  <- best so far
# epoch 29/100  lr 8.6e-04  train loss 0.001  train acc 1.000  val acc 0.492
# epoch 30/100  lr 8.5e-04  train loss 0.001  train acc 1.000  val acc 0.492
# epoch 31/100  lr 8.4e-04  train loss 0.001  train acc 1.000  val acc 0.495
# epoch 32/100  lr 8.3e-04  train loss 0.001  train acc 1.000  val acc 0.492
# epoch 33/100  lr 8.1e-04  train loss 0.001  train acc 1.000  val acc 0.485
# epoch 34/100  lr 8.0e-04  train loss 0.001  train acc 1.000  val acc 0.498  <- best so far
# epoch 35/100  lr 7.9e-04  train loss 0.001  train acc 1.000  val acc 0.505  <- best so far
# epoch 36/100  lr 7.7e-04  train loss 0.001  train acc 1.000  val acc 0.495
# epoch 37/100  lr 7.6e-04  train loss 0.001  train acc 1.000  val acc 0.499
# epoch 38/100  lr 7.5e-04  train loss 0.001  train acc 1.000  val acc 0.494
# epoch 39/100  lr 7.3e-04  train loss 0.001  train acc 1.000  val acc 0.490
# epoch 40/100  lr 7.2e-04  train loss 0.001  train acc 1.000  val acc 0.495
# epoch 41/100  lr 7.0e-04  train loss 0.001  train acc 1.000  val acc 0.493
# epoch 42/100  lr 6.9e-04  train loss 0.001  train acc 1.000  val acc 0.500
# epoch 43/100  lr 6.7e-04  train loss 0.000  train acc 1.000  val acc 0.496
# epoch 44/100  lr 6.5e-04  train loss 0.001  train acc 1.000  val acc 0.500
# epoch 45/100  lr 6.4e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 46/100  lr 6.2e-04  train loss 0.000  train acc 1.000  val acc 0.500
# epoch 47/100  lr 6.1e-04  train loss 0.000  train acc 1.000  val acc 0.497
# epoch 48/100  lr 5.9e-04  train loss 0.000  train acc 1.000  val acc 0.500
# epoch 49/100  lr 5.7e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 50/100  lr 5.6e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 51/100  lr 5.4e-04  train loss 0.000  train acc 1.000  val acc 0.495
# epoch 52/100  lr 5.2e-04  train loss 0.000  train acc 1.000  val acc 0.499
# epoch 53/100  lr 5.1e-04  train loss 0.000  train acc 1.000  val acc 0.502
# epoch 54/100  lr 4.9e-04  train loss 0.000  train acc 1.000  val acc 0.506  <- best so far
# epoch 55/100  lr 4.8e-04  train loss 0.000  train acc 1.000  val acc 0.506
# epoch 56/100  lr 4.6e-04  train loss 0.000  train acc 1.000  val acc 0.494
# epoch 57/100  lr 4.4e-04  train loss 0.000  train acc 1.000  val acc 0.513  <- best so far
# epoch 58/100  lr 4.3e-04  train loss 0.000  train acc 1.000  val acc 0.502
# epoch 59/100  lr 4.1e-04  train loss 0.000  train acc 1.000  val acc 0.500
# epoch 60/100  lr 3.9e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 61/100  lr 3.8e-04  train loss 0.000  train acc 1.000  val acc 0.498
# epoch 62/100  lr 3.6e-04  train loss 0.000  train acc 1.000  val acc 0.498
# epoch 63/100  lr 3.5e-04  train loss 0.000  train acc 1.000  val acc 0.504
# epoch 64/100  lr 3.3e-04  train loss 0.000  train acc 1.000  val acc 0.501
# epoch 65/100  lr 3.1e-04  train loss 0.000  train acc 1.000  val acc 0.504
# epoch 66/100  lr 3.0e-04  train loss 0.000  train acc 1.000  val acc 0.491
# epoch 67/100  lr 2.8e-04  train loss 0.000  train acc 1.000  val acc 0.502
# epoch 68/100  lr 2.7e-04  train loss 0.000  train acc 1.000  val acc 0.501
# epoch 69/100  lr 2.5e-04  train loss 0.000  train acc 1.000  val acc 0.501
# epoch 70/100  lr 2.4e-04  train loss 0.000  train acc 1.000  val acc 0.493
# epoch 71/100  lr 2.3e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 72/100  lr 2.1e-04  train loss 0.000  train acc 1.000  val acc 0.499
# epoch 73/100  lr 2.0e-04  train loss 0.000  train acc 1.000  val acc 0.496
# epoch 74/100  lr 1.9e-04  train loss 0.000  train acc 1.000  val acc 0.504
# epoch 75/100  lr 1.7e-04  train loss 0.000  train acc 1.000  val acc 0.498
# epoch 76/100  lr 1.6e-04  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 77/100  lr 1.5e-04  train loss 0.000  train acc 1.000  val acc 0.497
# epoch 78/100  lr 1.4e-04  train loss 0.000  train acc 1.000  val acc 0.496
# epoch 79/100  lr 1.3e-04  train loss 0.000  train acc 1.000  val acc 0.507
# epoch 80/100  lr 1.2e-04  train loss 0.000  train acc 1.000  val acc 0.506
# epoch 81/100  lr 1.1e-04  train loss 0.000  train acc 1.000  val acc 0.499
# epoch 82/100  lr 9.5e-05  train loss 0.000  train acc 1.000  val acc 0.501
# epoch 83/100  lr 8.6e-05  train loss 0.000  train acc 1.000  val acc 0.497
# epoch 84/100  lr 7.7e-05  train loss 0.000  train acc 1.000  val acc 0.497
# epoch 85/100  lr 6.8e-05  train loss 0.000  train acc 1.000  val acc 0.511
# epoch 86/100  lr 6.0e-05  train loss 0.000  train acc 1.000  val acc 0.505
# epoch 87/100  lr 5.3e-05  train loss 0.000  train acc 1.000  val acc 0.512
# epoch 88/100  lr 4.5e-05  train loss 0.000  train acc 1.000  val acc 0.499
# epoch 89/100  lr 3.9e-05  train loss 0.000  train acc 1.000  val acc 0.504
# epoch 90/100  lr 3.3e-05  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 91/100  lr 2.7e-05  train loss 0.000  train acc 1.000  val acc 0.500
# epoch 92/100  lr 2.2e-05  train loss 0.000  train acc 1.000  val acc 0.500
# epoch 93/100  lr 1.7e-05  train loss 0.000  train acc 1.000  val acc 0.498
# epoch 94/100  lr 1.3e-05  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 95/100  lr 9.8e-06  train loss 0.000  train acc 1.000  val acc 0.496
# epoch 96/100  lr 6.8e-06  train loss 0.000  train acc 1.000  val acc 0.507
# epoch 97/100  lr 4.4e-06  train loss 0.000  train acc 1.000  val acc 0.503
# epoch 98/100  lr 2.5e-06  train loss 0.000  train acc 1.000  val acc 0.492
# epoch 99/100  lr 1.1e-06  train loss 0.000  train acc 1.000  val acc 0.498
# epoch 100/100  lr 2.7e-07  train loss 0.000  train acc 1.000  val acc 0.499
#
# Saved epoch 57 (val accuracy 0.513) to Oxford_pets_scratch_noaugment.pth

# %%
train_loss_h, train_acc_h, val_acc_h = zip(*history)
epochs = range(1, len(history) + 1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4))
ax1.plot(epochs, train_acc_h, marker="o", label="train")
ax1.plot(epochs, val_acc_h, marker="o", label="val")
ax1.axvline(best_epoch, color="gray", linestyle=":", label=f"saved (epoch {best_epoch})")
ax1.set(title="Accuracy", xlabel="epoch")
ax1.legend()
ax2.plot(epochs, train_loss_h, marker="o")
ax2.set(title="Train loss", xlabel="epoch")
plt.tight_layout()
plt.show()

# %%
@torch.no_grad()
def collect(loader):
    model.eval()
    ys, preds = [], []
    for x, y in loader:
        preds.append(model(x.to(device)).argmax(1).cpu())
        ys.append(y)
    return torch.cat(ys).numpy(), torch.cat(preds).numpy()


y_true, y_pred = collect(test_loader)
test_acc = (y_true == y_pred).mean()

print(f"val  accuracy = {best_acc:.3f}  (used to pick the epoch)")
print(f"test accuracy = {test_acc:.3f}  (the number to report)")
print(f"{int((y_true != y_pred).sum())} wrong out of {len(y_true)} images\n")

print(classification_report(y_true, y_pred, target_names=class_names, digits=3, zero_division=0))

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(12, 10))
ax.imshow(cm, cmap="Blues")
ax.set_xticks(range(len(class_names)), class_names, rotation=60, ha="right", fontsize=8)
ax.set_yticks(range(len(class_names)), class_names, fontsize=8)
ax.set_xlabel("predicted")
ax.set_ylabel("actual")
ax.set_title(f"Confusion matrix - test accuracy {test_acc:.1%}")
plt.tight_layout()
plt.show()

mistakes = [(cm[i, j], class_names[i], class_names[j])
            for i in range(len(class_names)) for j in range(len(class_names)) if i != j and cm[i, j]]
print("Most confused pairs (actual -> predicted):")
for n, a, b in sorted(mistakes, reverse=True)[:10]:
    print(f"  {a} -> {b}  {n} images")
# Out:
# val  accuracy = 0.513  (used to pick the epoch)
# test accuracy = 0.540  (the number to report)
# 505 wrong out of 1098 images
#
#                             precision    recall  f1-score   support
#
#                 Abyssinian      0.459     0.586     0.515        29
#                     Bengal      0.679     0.633     0.655        30
#                     Birman      0.629     0.733     0.677        30
#                     Bombay      0.633     0.731     0.679        26
#          British_Shorthair      0.500     0.567     0.531        30
#               Egyptian_Mau      0.579     0.786     0.667        28
#                 Maine_Coon      0.500     0.400     0.444        30
#                    Persian      0.467     0.467     0.467        30
#                    Ragdoll      0.436     0.567     0.493        30
#               Russian_Blue      0.481     0.433     0.456        30
#                    Siamese      0.556     0.500     0.526        30
#                     Sphynx      0.533     0.533     0.533        30
#           american_bulldog      0.355     0.367     0.361        30
#  american_pit_bull_terrier      0.154     0.067     0.093        30
#               basset_hound      0.481     0.433     0.456        30
#                     beagle      0.594     0.633     0.613        30
#                      boxer      0.385     0.333     0.357        30
#                  chihuahua      0.375     0.200     0.261        30
#     english_cocker_spaniel      0.500     0.200     0.286        30
#             english_setter      0.472     0.567     0.515        30
#         german_shorthaired      0.429     0.400     0.414        30
#             great_pyrenees      0.571     0.667     0.615        30
#                   havanese      0.480     0.400     0.436        30
#              japanese_chin      0.724     0.724     0.724        29
#                   keeshond      0.606     0.690     0.645        29
#                 leonberger      0.704     0.633     0.667        30
#         miniature_pinscher      0.452     0.467     0.459        30
#               newfoundland      0.513     0.690     0.588        29
#                 pomeranian      0.500     0.467     0.483        30
#                        pug      0.885     0.767     0.821        30
#              saint_bernard      0.676     0.767     0.719        30
#                    samoyed      0.538     0.700     0.609        30
#           scottish_terrier      0.545     0.600     0.571        30
#                  shiba_inu      0.655     0.633     0.644        30
# staffordshire_bull_terrier      0.348     0.286     0.314        28
#            wheaten_terrier      0.525     0.700     0.600        30
#          yorkshire_terrier      0.778     0.700     0.737        30
#
#                   accuracy                          0.540      1098
#                  macro avg      0.532     0.541     0.531      1098
#               weighted avg      0.532     0.540     0.530      1098
# Most confused pairs (actual -> predicted):
#   Russian_Blue -> British_Shorthair  10 images
#   Siamese -> Birman  8 images
#   english_cocker_spaniel -> english_setter  7 images
#   Maine_Coon -> Abyssinian  7 images
#   havanese -> great_pyrenees  6 images
#   Persian -> Maine_Coon  6 images
#   basset_hound -> beagle  5 images
#   american_pit_bull_terrier -> american_bulldog  5 images
#   Persian -> Ragdoll  5 images
#   scottish_terrier -> newfoundland  4 images

# %%
MAX_SHOW = 10
mean = torch.tensor(NORM_MEAN).view(3, 1, 1)
std = torch.tensor(NORM_STD).view(3, 1, 1)

wrong = []
for i, (t, p) in enumerate(zip(y_true, y_pred)):
    if t != p and len(wrong) < MAX_SHOW:
        img, _ = test_ds[i]
        wrong.append((img * std + mean, class_names[t], class_names[p]))   # undo Normalize so the colors look right

fig, axes = plt.subplots(3, 4, figsize=(10, 8.5))
for ax in axes.flat:
    ax.axis("off")
for ax, (img, t, p) in zip(axes.flat, wrong):
    ax.imshow(img.permute(1, 2, 0).clamp(0, 1))
    ax.set_title(f"true: {t}\npred: {p}", fontsize=9, color="tab:red")
plt.tight_layout()
plt.show()

# %%
CKPT_PATH = "Oxford_pets_scratch_noaugment.pth"

ckpt = torch.load(CKPT_PATH, map_location="cpu", weights_only=True)
names = ckpt["class_names"]

net = models.resnet18()
net.fc = nn.Linear(net.fc.in_features, len(names))
net.load_state_dict(ckpt["model_state"])
net = net.to(device).eval()

tf = transforms.Compose([
    transforms.Resize((ckpt["img_size"], ckpt["img_size"])),
    transforms.ToTensor(),
    transforms.Normalize(ckpt["norm_mean"], ckpt["norm_std"]),
])

print(f"Loaded {CKPT_PATH}: epoch {ckpt['epoch']}, val accuracy {ckpt['val_accuracy']:.3f}, {len(names)} classes")
# Out:
# Loaded Oxford_pets_scratch_noaugment.pth: epoch 57, val accuracy 0.513, 37 classes

# %%
def open_image(path):
    return ImageOps.exif_transpose(Image.open(path)).convert("RGB")   # exif_transpose turns phone photos the right way up


@torch.no_grad()
def predict(path, topk=3):
    x = tf(open_image(path)).unsqueeze(0).to(device)
    probs = torch.softmax(net(x), dim=1)[0]
    p, i = probs.topk(topk)
    return [(names[c], v.item()) for v, c in zip(p, i)]


def show(path, topk=3):
    top = predict(path, topk)
    plt.figure(figsize=(4, 4))
    plt.imshow(open_image(path))
    plt.axis("off")
    plt.title(f"{top[0][0]}  ({top[0][1]:.1%})")
    plt.show()
    for name, conf in top:
        print(f"  {name:<28} {conf:6.1%}")


NEW_DIR = Path.home()/"Downloads"/"new_pets"
NEW_DIR.mkdir(parents=True, exist_ok=True)
new_images = [p for p in sorted(NEW_DIR.iterdir()) if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp", ".webp"}]

if not new_images:
    print(f"No images in {NEW_DIR} yet - put some there and run this cell again")
for path in new_images[:10]:    
    print(path.name)
    show(path)
# Out:
# No images in C:\Users\Lenovo\Downloads\new_pets yet - put some there and run this cell again
